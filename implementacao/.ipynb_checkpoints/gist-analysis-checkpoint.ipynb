# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
data = pd.read_csv('GIST/gistdescriptor/saida_base-tcc2.csv')
data = data.rename(columns={'513': 'movimento'})

# %%
data.head()
# Out:
#           1         2         3         4         5         6         7  \
# 0  0.086274  0.071821  0.077652  0.076096  0.049158  0.079816  0.042151
# 1  0.023998  0.024274  0.033803  0.025671  0.017888  0.026377  0.034349
# 2  0.020446  0.052234  0.040775  0.036538  0.014265  0.034920  0.058066
# 3  0.005151  0.032158  0.042421  0.035123  0.007478  0.022105  0.028233
# 4  0.053968  0.048947  0.060233  0.076032  0.030523  0.023192  0.028408
#
#           8         9        10    ...           504       505       506  \
# 0  0.055955  0.063861  0.057440    ...      0.065093  0.066270  0.081336
# 1  0.029231  0.024245  0.032683    ...      0.042860  0.057011  0.065712
# 2  0.039064  0.034149  0.038502    ...      0.052573  0.070772  0.066052
# 3  0.010758  0.009418  0.031849    ...      0.017827  0.030627  0.098616
# 4  0.019715  0.040361  0.032498    ...      0.079197  0.056681  0.074158
#
#         507       508       509       510       511       512  movimento
# 0  0.058597  0.063123  0.078648  0.073356  0.114600  0.128160    cubismo
# 1  0.053308  0.069223  0.049543  0.115160  0.073370  0.058538    cubismo
# 2  0.065886  0.101130  0.074187  0.086574  0.039541  0.105910    cubismo
# 3  0.063128  0.048063  0.032065  0.084744  0.089166  0.084518    cubismo
# 4  0.044215  0.046421  0.028135  0.026498  0.040113  0.101160    cubismo
#
# [5 rows x 513 columns]

# %%
X = data.drop(['movimento'], axis=1)
Y = data['movimento']

# %%
X.head()
# Out:
#           1         2         3         4         5         6         7  \
# 0  0.086274  0.071821  0.077652  0.076096  0.049158  0.079816  0.042151
# 1  0.023998  0.024274  0.033803  0.025671  0.017888  0.026377  0.034349
# 2  0.020446  0.052234  0.040775  0.036538  0.014265  0.034920  0.058066
# 3  0.005151  0.032158  0.042421  0.035123  0.007478  0.022105  0.028233
# 4  0.053968  0.048947  0.060233  0.076032  0.030523  0.023192  0.028408
#
#           8         9        10    ...          503       504       505  \
# 0  0.055955  0.063861  0.057440    ...     0.055280  0.065093  0.066270
# 1  0.029231  0.024245  0.032683    ...     0.042323  0.042860  0.057011
# 2  0.039064  0.034149  0.038502    ...     0.128830  0.052573  0.070772
# 3  0.010758  0.009418  0.031849    ...     0.052570  0.017827  0.030627
# 4  0.019715  0.040361  0.032498    ...     0.050365  0.079197  0.056681
#
#         506       507       508       509       510       511       512
# 0  0.081336  0.058597  0.063123  0.078648  0.073356  0.114600  0.128160
# 1  0.065712  0.053308  0.069223  0.049543  0.115160  0.073370  0.058538
# 2  0.066052  0.065886  0.101130  0.074187  0.086574  0.039541  0.105910
# 3  0.098616  0.063128  0.048063  0.032065  0.084744  0.089166  0.084518
# 4  0.074158  0.044215  0.046421  0.028135  0.026498  0.040113  0.101160
#
# [5 rows x 512 columns]

# %%
Y.head()
# Out:
# 0    cubismo
# 1    cubismo
# 2    cubismo
# 3    cubismo
# 4    cubismo
# Name: movimento, dtype: object

# %%
data['movimento'].value_counts().plot(kind='bar', rot=60, fontsize=12)

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=10)
##for train_index, test_index in kfold.split(X):

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

clf_rf = RandomForestClassifier(random_state=0)

param_grid = {"max_depth": [3, None],
              "max_features": [1, 3, 10],
              "min_samples_split": [2, 3, 10],
              "min_samples_leaf": [1, 3, 10],
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

grid_search = GridSearchCV(clf_rf, param_grid=param_grid)
grid_search.fit(X, Y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
results_rf = cross_val_score(grid_search, X, Y, cv=kfold)
print (results_rf.mean())
# Out:
# 0.075
